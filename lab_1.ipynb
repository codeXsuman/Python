# %% [markdown]
# <a href="https://colab.research.google.com/github/codeXsuman/Python/blob/main/lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LAB_1 ASSIGMENTS**
#
# ---
# [Assigment(Unit 1)](https://drive.google.com/file/d/1f6DyQCBoUk52cT8jgSYHWbbcpvt-H_Od/view?usp=classroom_web&authuser=0)

# %%
print("hello world!")
# Out:
# hello world!

# %%
print("SUMAN NANDI")
# Out:
# SUMAN NANDI

# %%
print("Haldia Institute of Technology")
# Out:
# Haldia Institute of Technology

# %%
print("good morning")
print("good afternoon")
print("good evening")
# Out:
# good morning
# good afternoon
# good evening

# %%
x = 77
print(x)
# Out:
# 77

# %%
amount = 2310.59
print(amount)
# Out:
# 2310.59

# %%
name = "suman"
print(name)
# Out:
# suman

# %%
x = False
print(x)
# Out:
# False

# %%
product = "coffee"
price = 60
discount = 10.99
present = True
print(product, price, discount, present)
# Out:
# coffee 60 10.99 True

# %%
a = 10
b = 20
c = 30
print(a, b, c)
# Out:
# 10 20 30

# %%
a=b=c=10
print(a,b,c)
# Out:
# 10 10 10

# %%
k = 10
print(k)
k = 50
print(k)
# Out:
# 10
# 50

# %%
age = 30
name = "krish"
marks = 89.70
passed = True
print(type(age))
print(type(name))
print(type(marks))
print(type(passed))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
x = 68
print(x)
del(x)
# print(x) # ERROR
# Out:
# 68

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name: suman
# suman

# %%
age = input("Enter your age: ")
print(age)
# Out:
# Enter your age: 100
# 100

# %%
amount = input("Enter amount: ")
print(amount)
# Out:
# Enter amount: 12000.500
# 12000.500

# %%
name = input("Enter your name: ")
age = int(input("Enter age: "))
print("name is: ", name)
print("Age is: ", age)
# Out:
# Enter your name: frank
# Enter age: 99
# name is:  frank
# Age is:  99

# %%
name = input("Enter your name: ")
print("Hey good morning", name, "How are you?")
# Out:
# Enter your name: alex
# Hey good morning alex How are you?

# %%
a = 10
b = 20
sum = a + b
print(sum)
# Out:
# 30

# %%
a = 70
b = 20
difference = a - b
print(difference)
# Out:
# 50

# %%
a = 10
b = 20
product = a * b
print(product)
# Out:
# 200

# %%
a = 100
b = 20
div = a / b
print(div)
# Out:
# 5.0

# %%
a = 40
b = 4
remainder = a%b
print(remainder)
# Out:
# 0

# %%
a = 41
b = 2
floor = a//b
print("floor = ", floor)
# Out:
# floor =  20

# %%
#26...
