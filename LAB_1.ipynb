# %% [markdown]
# <a href="https://colab.research.google.com/github/codeXsuman/Python/blob/main/LAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LAB_1 ASSIGMENTS**
#
# ---
# [Assigment(Unit 1)](https://drive.google.com/file/d/1f6DyQCBoUk52cT8jgSYHWbbcpvt-H_Od/view?usp=classroom_web&authuser=0)

# %%
# 1
print("hello world!")
# Out:
# hello world!

# %%
# 2
print("SUMAN NANDI")
# Out:
# SUMAN NANDI

# %%
# 3
print("Haldia Institute of Technology")
# Out:
# Haldia Institute of Technology

# %%
# 4
print("good morning")
print("good afternoon")
print("good evening")
# Out:
# good morning
# good afternoon
# good evening

# %%
# 5
x = 77
print(x)
# Out:
# 77

# %%
# 6
amount = 2310.59
print(amount)
# Out:
# 2310.59

# %%
# 7
name = "suman"
print(name)
# Out:
# suman

# %%
# 8
x = False
print(x)
# Out:
# False

# %%
# 9
product = "coffee"
price = 60
discount = 10.99
present = True
print(product, price, discount, present)
# Out:
# coffee 60 10.99 True

# %%
# 10
a = 10
b = 20
c = 30
print(a, b, c)
# Out:
# 10 20 30

# %%
# 11
a=b=c=10
print(a,b,c)
# Out:
# 10 10 10

# %%
# 12
k = 10
print(k)
k = 50
print(k)
# Out:
# 10
# 50

# %%
# 13
age = 30
name = "krish"
marks = 89.70
passed = True
print(type(age))
print(type(name))
print(type(marks))
print(type(passed))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
# 14
x = 68
print(x)
del(x)
# print(x) # ERROR
# Out:
# 68

# %%
# 15
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name: suman
# suman

# %%
# 16
age = input("Enter your age: ")
print(age)
# Out:
# Enter your age: 100
# 100

# %%
# 17
amount = input("Enter amount: ")
print(amount)
# Out:
# Enter amount: 12000.500
# 12000.500

# %%
# 18
name = input("Enter your name: ")
age = int(input("Enter age: "))
print("name is: ", name)
print("Age is: ", age)
# Out:
# Enter your name: frank
# Enter age: 99
# name is:  frank
# Age is:  99

# %%
# 19
name = input("Enter your name: ")
print("Hey good morning", name, "How are you?")
# Out:
# Enter your name: alex
# Hey good morning alex How are you?

# %%
# 20
a = 10
b = 20
sum = a + b
print(sum)
# Out:
# 30

# %%
# 21
a = 70
b = 20
difference = a - b
print(difference)
# Out:
# 50

# %%
# 22
a = 10
b = 20
product = a * b
print(product)
# Out:
# 200

# %%
# 23
a = 100
b = 20
div = a / b
print(div)
# Out:
# 5.0

# %%
# 24
a = 40
b = 4
remainder = a%b
print(remainder)
# Out:
# 0

# %%
# 25
a = 41
b = 2
floor = a//b
print("floor = ", floor)
# Out:
# floor =  20

# %%
# 26
a = 2
b = 3
power = a ** b
print(power)
# Out:
# 8

# %%
# 27
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
Total = num1 + num2
print ("sum is =", Total)
# Out:
# Enter first number: 20
# Enter second number: 30
# sum is = 50

# %%
# 28
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter first number: "))
avg = (a+b+c)/3
print("average is:", avg)
# Out:
# Enter first number: 10
# Enter second number: 20
# Enter first number: 30
# average is: 20.0

# %%
# 29
length = float(input("Enter Length: "))
breadth = float(input("Enter Breadth: "))
perimeter = 2 * (length + breadth)
print("perimeter is:", perimeter)
# Out:
# Enter Length: 7
# Enter Breadth: 5
# perimeter is: 24.0

# %%
# 30
length = float(input("Enter Length: "))
breadth = float(input("Enter Breadth: "))
area = length * breadth
print("area is:", area)
# Out:
# Enter Length: 7
# Enter Breadth: 5
# area is: 35.0

# %%
# 31
a = float(input("enter the side of a square: "))
area = a * a
perimeter = 4 * a
print("Area is =", area)
print("perimeter is =", perimeter)
# Out:
# enter the side of a square: 7
# Area is = 49.0
# perimeter is = 28.0

# %%
# 32
radius = float(input("Enter radius: "))
area = 3.14 * radius * radius
print("Area is =", area)
# Out:
# Enter radius: 7
# Area is = 153.86

# %%
# 33
radius = float(input("Enter radius: "))
circumtence = 2 * 3.14 * radius
print("circumtence is =", circumtence)
# Out:
# Enter radius: 7
# circumtence is = 43.96

# %%
# 34
num = int(input("Enter a number: "))
square = num ** 2
print("Square =", square)
# Out:
# Enter a number: 7
# Square = 49

# %%
# 35
num = int(input("Enter a number: "))
cube = num ** 3
print("cube =", cube)
# Out:
# Enter a number: 5
# cube = 125

# %%
# 36
celsius = float(input("Enter temperature: "))
fahrenheit = (celsius * 9/5) +32
print(fahrenheit)
# Out:
# Enter temperature: 20
# 68.0

# %%
# 37
fahrenheit = float(input("Enter temperature: "))
celsius = (fahrenheit - 32) * 5/9
print(celsius)
# Out:
# Enter temperature: 68
# 20.0

# %%
# 38
num1 = 10
num2 = 20
num3 = num1
num1 = num2
num2 = num3
print("num1 =", num1)
print("num2 =", num2)
# Out:
# num1 = 20
# num2 = 10

# %%
# 39
num1 = 50
num2 = 45
num1,num2 = num2,num1
print("num1 =", num1)
print("num2 =", num2)
# Out:
# num1 = 45
# num2 = 50

# %%
# 40
P = float(input("Enter the principle amount: "))
R = float(input("Enter the rate: "))
T = float(input("Enter the time: "))
simple_interest = (P*R*T)/100
print("Simple Interest is =", simple_interest)
# Out:
# Enter the principle amount: 12000
# Enter the rate: 7
# Enter the time: 5
# Simple Interest is = 4200.0

# %%
# 41
num = input("Enter a number as a string: ")
num = int(num)
print("Integer Value =", num)
# Out:
# Enter a number as a string: 56
# Integer Value = 56

# %%
# 42
num = float(input("Enter a number: "))
num = int(num)
print("Integer Value =", num)
# Out:
# Enter a number: 22.7
# Integer Value = 22

# %%
# 43
num = int(input("Enter a number: "))
num = float(num)
print("Integer Value =", num)
# Out:
# Enter a number: 22
# Integer Value = 22.0

# %%
# 44
number = 45
text = str(number)
print(text)
print(type(text))
# Out:
# 45
# <class 'str'>

# %%
# 45
num = input("Enter a number: ")
print("Before conversion:", type(num))
num = int(num)
print("After conversion:", type(num))
# Out:
# Enter a number: 7
# Before conversion: <class 'str'>
# After conversion: <class 'int'>

# %%
# 46
num1 = 67
num2 = 28

print("Greater:", num1 > num2)
print("Equal:", num1 == num2)
print("Not Equal:", num1 != num2)
print("less:", num1 < num2)
print("Greater than or equal:", num1 >= num2)
print("Lesss than or equal:", num1<= num2)
# Out:
# Greater: True
# Equal: False
# Not Equal: True
# less: False
# Greater than or equal: True
# Lesss than or equal: False

# %%
# 47
Ticlet_available = True
has_id = False
Enter = Ticlet_available and has_id
print(Enter)
# Out:
# False

# %%
# 48
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print((a>0) or (b>0))
# Out:
# Enter first number: 5
# Enter second number: 0
# True

# %%
# 49
a = int(input("Enter a number: "))
print(not(a>0))
# Out:
# Enter a number: 5
# False

# %%
# 50
text = input("Enter a string: ")
char = input("enter a cheracter: ")
print(char in text)
# Out:
# Enter a string: I love coffee
# enter a cheracter: love
# True

# %% [markdown]
# END
